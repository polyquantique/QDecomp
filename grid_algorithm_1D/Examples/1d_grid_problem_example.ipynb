# %%
import sys
import os
sys.path.append(os.path.dirname(os.getcwd()))
from grid_algorithm_1D import solve_grid_problem_1d
from matplotlib import pyplot
pyplot.rcParams['figure.dpi'] = 300

# %% [markdown]
# # Example 1
#
# $A = \left[3, 7\right]$, $B = \left[-10, 2\right]$
#
# Solutions: $\{\alpha \in \mathbb{Z}\left[\sqrt{2}\right] |\ \alpha \in A,\ \alpha^\bullet \in B\}$

# %%
solutions = solve_grid_problem_1d((3, 7), (-10, 2), plot_solutions=True)
print(solutions)
# Out:
# 16 solutions were found.
# [3 + 1√2, 4 + 2√2, 2 + 1√2, 3 + 2√2, 2 + 2√2, 1 + 2√2, 2 + 3√2, 1 + 3√2, 0 + 3√2, 1 + 4√2, -1 + 3√2, 0 + 4√2, -1 + 4√2, -2 + 4√2, -1 + 5√2, -2 + 5√2]

# %% [markdown]
# # Example 2
#
# $A = \left[-2, 2\right]$, $B = \left[-5, 5\right]$
#
# Solutions: $\{\alpha \in \mathbb{Z}\left[\sqrt{2}\right] |\ \alpha \in A,\ \alpha^\bullet \in B\}$

# %%
solutions = solve_grid_problem_1d((-2, 2), (-5, 5), plot_solutions=True)
print(solutions)
# Out:
# 17 solutions were found.
# [2 - 2√2, 3 - 1√2, 1 - 2√2, 2 - 1√2, 1 - 1√2, 2 + 0√2, 0 - 1√2, 1 + 0√2, 0 + 0√2, -1 + 0√2, 0 + 1√2, -2 + 0√2, -1 + 1√2, -2 + 1√2, -1 + 2√2, -3 + 1√2, -2 + 2√2]

# %% [markdown]
# # Example 3
#
# $A = \left[2, 5\right]$, $B = \left[-5, 2\right]$
#
# Solutions: $\{\alpha \in \mathbb{Z}\left[\sqrt{2}\right] |\ \alpha \in A,\ \alpha^\bullet \in B\}$

# %%
solutions = solve_grid_problem_1d((2, 5), (-5, -2), plot_solutions=True)
print(solutions)
# Out:
# 2 solutions were found.
# [0 + 2√2, 0 + 3√2]

# %% [markdown]
# # Example 4
#
# $A = \left[1.2, 1.6\right]$, $B = \left[-5, 2\right]$
#
# Solutions: $\{\alpha \in \mathbb{Z}\left[\sqrt{2}\right] |\ \alpha \in A,\ \alpha^\bullet \in B\}$

# %%
solutions = solve_grid_problem_1d((1.2, 1.6), (-5, -2), plot_solutions=True)
print(solutions)
# Out:
# No solutions were found for the grid problem.
# []
